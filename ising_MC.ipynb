# %% [markdown]
# # Modelo de Ising Através de Simulações de Monte Carlo
# **Alice Barbarino Santos e Felipe David Crasto de Lima**

# %% [markdown]
# Neste notebook, construído no projeto Magnetismo e Estruturas Bidimensionais: Investigando Organometálicos de Ftalocianinas, é implementada uma simulação de Monte Carlo com algoritmo de Metropolis para o modelo de Ising bidimensional isotrópico em uma rede quadrada L $\times$ L, a fim de estimar a magnetização e a temperatura crítica de transição de fase de diferentes geometrias de ftalocianinas. Assumimos valores de spin de $\pm$ 1 e considerando apenas interações com primeiros vizinhos.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from au_mof import *

# %% [markdown]
# Definimos o tamanho da rede quadrada:

# %%
L = 40

# %%
Agora é possível observar grandezas termodinâmicas como para cada geometria simulada:

# %% [markdown]
# ### 0 anéis

# %%
Eaf = -293.69782149/8
Efm = -74.01943058/2

Tc = plotar_todos_resultados(L, Eaf , Efm, nome_do_arquivo = "0_aneis")
# Out:
# 100%|██████████| 40/40 [32:18<00:00, 48.47s/it]
# Temperatura crítica estimada (pico de C_v): 0.334
# Temperatura crítica estimada (pico de χ): 0.155
# Temperatura crítica média estimada: 0.244

# %% [markdown]
# ### 1 anel

# %%
Eaf = -1074.09685815/8
Efm = -268.58038580/2

Tc = plotar_todos_resultados(L, Eaf, Efm, nome_do_arquivo = "1_anel")
# Out:
# 100%|██████████| 40/40 [56:24<00:00, 84.61s/it]
# Temperatura crítica estimada (pico de C_v): 0.027
# Temperatura crítica estimada (pico de χ): 0.052
# Temperatura crítica média estimada: 0.039

# %% [markdown]
# ### 2 anéis

# %%
Eaf = -1419.52471968/8
Efm = -354.07797161/2

Tc = plotar_todos_resultados(L, Eaf, Efm, nome_do_arquivo = "2_aneis")
# Out:
# 100%|██████████| 40/40 [1:25:57<00:00, 128.95s/it]
# Temperatura crítica estimada (pico de C_v): 0.436
# Temperatura crítica estimada (pico de χ): 0.616
# Temperatura crítica média estimada: 0.526

# %% [markdown]
# ### 3 anéis

# %%
Eaf= -1763.76440986/8
Efm= -441.814780402/2

Tc = plotar_todos_resultados(L, Eaf, Efm, nome_do_arquivo = "3_aneis")
# Out:
# 100%|██████████| 40/40 [3:16:05<00:00, 294.13s/it]
# Temperatura crítica estimada (pico de C_v): 0.411
# Temperatura crítica estimada (pico de χ): 0.411
# Temperatura crítica média estimada: 0.411

# %% [markdown]
# ## Referências:

# %% [markdown]
# [1] BLUNDELL, S. Magnetism in Condensed Matter. OUP Oxford, 2001. (Oxford Master Series in Condensed Matter Physics). ISBN 9780198505914. Disponível em: <https://books.google.com.br/books?id=OGhGmgEACAAJ>.
#
# [2] ABEL, M. et al. Single layer of polymeric fe-phthalocyanine: An organometallic sheet on metal and thin insulating film. Journal of the American Chemical Society, American Chemical Society (ACS), v. 133, n. 5, p. 1203–1205, dez. 2010. ISSN 1520-5126. Disponível em: <http://dx.doi.org/10.1021/ja108628r>.
#
# [3] ONSAGER, L. Crystal statistics. i. a two-dimensional model with an order-disorder transition. Phys. Rev., American Physical Society, v. 65, p. 117–149, Feb 1944. Disponível em: <https://link.aps.org/doi/10.1103/PhysRev.65.117>.
